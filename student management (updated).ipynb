# %%
log=[]
course=[]

# %%
def users():
    while True:
        no=int(input("Enter a number of user you want to create:"))
        for i in range(no):
            username=input(f"Enter a user {i+1} name:").lower()
            password=input(f"Enter a {i+1} Password:")
            log.append([username,password])
            courses()
        check=input("What you want to check: \n1: Count of users \n2:want to search any user? \n3:want to remove any user? \n4: want to add any user? \nPress any for exit:")
        if check=="1":
            print(f"Total Number of Users are: {len(log)}")
            break
        elif check=="2":
            lst=[]
            for i in range(len(log)):
                lst.append(log[i][0])
            check2=input("Enter a name of user you want to search:").lower()
            count=lst.count(check2)
            if count>0:
                print("User Exist!")
                break
            else:
                print("User Does not Exist!")
                break
        elif check=="3":
            lst=[]
            for i in range(len(log)):
                lst.append(log[i][0])
            check2=input("Enter a name of user you want to remove?").lower()
            var=lst.index(check2)
            print(log.pop(var))
            print(f"updated User details are :{log}")
            
            
        elif check == "4":
            continue
        else:
            print("Thank you for using Admin portal!")
            break
                
        break

def courses():
    while True:
        num=int(input("Enter a number of courses you want to add?:"))
        if num>=10:
            print("You have exceeded the limit of courses:!")
            break
        else:
            all=[]
            for i in range(1,num+1):
                name=input("Enter a name of course you want to add:")
                all.append(name)
                print(all)
            course.append(all)
            print(course)  
            
        rerun=input("Do you want to add courses for further students? (yes or no):").lower()
        if rerun=="yes":
            continue
        else:

            break

# %%
def profile():
    user1=input("Enter a user name:")
    passw=input("Enter a password:")
   
    checkuser=[]
    checkpass=[]
    for i in range(len(log)):
        chk=log[i][0]
        checkuser.append(chk)
    for j in range (len(log)):
        chk2=log[j][1]
        checkpass.append(chk2)
    if (user1 in checkuser) and (passw in checkpass):
        a=checkuser.index(user1)
        b=checkpass.index(passw)
        if a==b:
            print("Login Succeeeded!")
        
        print(f"Dear Student! {user1} your Courses are : {course[a]}")
        fee=(len(course[a]))*1500
        print(f"total no. of Registered Courses: {len(course[a])} \nYour Total Fees is Rs.{fee}")
        
    else:
        print("user not found")

# %%
## print("Welcome to School Management System")
def program():
    while True:
        select=input("What you want to do?: \n1:Add students id \n2:courses: \n3:Student Profile login")
        if select=="1":
            users()
            print(f"Please add Courses of {len(log)} students!")
        elif select=="2":
            #courses()
            print("System Under Development")
            break
        elif select=="3":
            profile()
            break
        else:
            print("Invalid Input")
            break
        rerun=input("Do you want to continue? (yes or no):")
        if rerun=="yes":
            continue
        else:
            break

# %%
program()
# Out:
# What you want to do?:
# 1:Add students id
# 2:courses:
# 3:Student Profile login 1
# Enter a number of user you want to create: 3
# Enter a user 1 name: sahir lodhi
# Enter a 1 Password: 123
# Enter a number of courses you want to add?: 3
# Enter a name of course you want to add: physics
# ['physics']
# Enter a name of course you want to add: maths
# ['physics', 'maths']
# Enter a name of course you want to add: modeling
# ['physics', 'maths', 'modeling']
# [['physics', 'maths', 'modeling']]
# Do you want to add courses for further students? (yes or no): no
# Enter a user 2 name: abu bakar
# Enter a 2 Password: 123
# Enter a number of courses you want to add?: 3
# Enter a name of course you want to add: AI
# ['AI']
# Enter a name of course you want to add: OS
# ['AI', 'OS']
# Enter a name of course you want to add: SDA
# ['AI', 'OS', 'SDA']
# [['physics', 'maths', 'modeling'], ['AI', 'OS', 'SDA']]
# Do you want to add courses for further students? (yes or no): no
# ...

# %%
log
# Out:
# [['rafay', '123'],
#  ['umer', '123'],
#  ['hadi', '123'],
#  ['tariq', '123'],
#  ['anousha', '123'],
#  ['saboora', '123'],
#  ['shereen', '123'],
#  ['rida', '123'],
#  ['akbar', '123'],
#  ['aziz', '123']]

# %%
course
# Out:
# [['pyshics', 'maths', 'chemistry'],
#  ['sindhi', 'urdu', 'english'],
#  ['english', 'islamiat'],
#  ['physics', 'chemistry']]

# %%
userd=[]
for i in range(len(log)):
    print(f"{i+1}-{log[i][0]}")

delete=int(input("Which user you want to delete?:"))
log.pop(delete-1)
course.pop(delete-1)

print(f"Update Students are:")
for i in range(len(log)):
    print(f"{i+1}-{log[i][0]}")
# Out:
# 1-rafay
# 2-umer
# 3-hadi
# 4-tariq
# 5-anousha
# 6-saboora
# 7-shereen
# 8-rida
# 9-akbar
# Which user you want to delete?: 2
# Update Students are:
# 1-rafay
# 2-hadi
# 3-tariq
# 4-anousha
# 5-saboora
# 6-shereen
# 7-rida
# 8-akbar

# %%
ab=["rafay",123,"umer","hello","ali","adil","ali","rafay"]

# %%
ab.index("rafay",1)
# Out:
# 7
